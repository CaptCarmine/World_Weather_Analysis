# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import time
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4873d446723675828e7558706dff1124

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wind_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wind_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | almaznyy
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | borujerd
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | gat
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | waipawa
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | trapani
# Processing Record 17 of Set 1 | skibbereen
# Processing Record 18 of Set 1 | pisco
# Processing Record 19 of Set 1 | washington
# Processing Record 20 of Set 1 | eureka
# Processing Record 21 of Set 1 | sakaiminato
# Processing Record 22 of Set 1 | pringsewu
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 1 | xuddur
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | marshall
# Processing Record 28 of Set 1 | marawi
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | margate
# Processing Record 35 of Set 1 | taltal
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | nouadhibou
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | mana
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | sokoto
# Processing Record 43 of Set 1 | dakor
# Processing Record 44 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 1 | bud
# Processing Record 46 of Set 1 | poshekhonye
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | flinders
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | batemans bay
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | mandiana
# Processing Record 9 of Set 2 | haapiti
# Processing Record 10 of Set 2 | mahenge
# Processing Record 11 of Set 2 | ourossogui
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | sutton
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | lagunas
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | badulla
# Processing Record 22 of Set 2 | te anau
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | laguna
# Processing Record 26 of Set 2 | noumea
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | puerto escondido
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | broken hill
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | inuvik
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | paamiut
# Processing Record 37 of Set 2 | vila velha
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | sigmaringen
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | omboue
# Processing Record 43 of Set 2 | zeya
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | strezhevoy
# Processing Record 49 of Set 2 | sitka
# Processing Record 50 of Set 2 | pangkalanbuun
# Processing Record 1 of Set 3 | lalomanu
# City not found. Skipping...
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | huarmey
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | luorong
# Processing Record 7 of Set 3 | chara
# Processing Record 8 of Set 3 | angoram
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | markova
# Processing Record 14 of Set 3 | kankavli
# City not found. Skipping...
# Processing Record 15 of Set 3 | talnakh
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | sabang
# Processing Record 19 of Set 3 | angermunde
# Processing Record 20 of Set 3 | kassala
# Processing Record 21 of Set 3 | dunedin
# Processing Record 22 of Set 3 | kaeo
# Processing Record 23 of Set 3 | camacha
# Processing Record 24 of Set 3 | arkhangelsk
# Processing Record 25 of Set 3 | green river
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | dingle
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | klyuchi
# Processing Record 31 of Set 3 | mangai
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | dagumba-an
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | kyabe
# Processing Record 36 of Set 3 | mahajanga
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | pathein
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | merauke
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | buala
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | morant bay
# Processing Record 47 of Set 3 | torrington
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | jackson
# Processing Record 50 of Set 3 | agirish
# Processing Record 1 of Set 4 | valtotopion
# Processing Record 2 of Set 4 | marsa matruh
# Processing Record 3 of Set 4 | westport
# Processing Record 4 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 4 | erdenet
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | abu kamal
# Processing Record 8 of Set 4 | areosa
# Processing Record 9 of Set 4 | malangali
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 4 | boueni
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | tamandare
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | caravelas
# Processing Record 19 of Set 4 | bitung
# Processing Record 20 of Set 4 | praya
# Processing Record 21 of Set 4 | angoche
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | banes
# Processing Record 24 of Set 4 | garissa
# Processing Record 25 of Set 4 | russell
# Processing Record 26 of Set 4 | camocim
# Processing Record 27 of Set 4 | kununurra
# Processing Record 28 of Set 4 | burladingen
# Processing Record 29 of Set 4 | hrodna
# Processing Record 30 of Set 4 | erzin
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | zhigansk
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | upington
# Processing Record 35 of Set 4 | taoudenni
# Processing Record 36 of Set 4 | halifax
# Processing Record 37 of Set 4 | cantapoy
# Processing Record 38 of Set 4 | traiguen
# Processing Record 39 of Set 4 | krasnoselkup
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | deputatskiy
# Processing Record 42 of Set 4 | quelimane
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | banda aceh
# Processing Record 45 of Set 4 | severobaykalsk
# Processing Record 46 of Set 4 | aktash
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | madinat sittah uktubar
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | lishui
# Processing Record 4 of Set 5 | monroe
# Processing Record 5 of Set 5 | namatanai
# Processing Record 6 of Set 5 | hue
# Processing Record 7 of Set 5 | surt
# Processing Record 8 of Set 5 | batagay
# Processing Record 9 of Set 5 | kapit
# Processing Record 10 of Set 5 | vao
# Processing Record 11 of Set 5 | porto novo
# Processing Record 12 of Set 5 | hailar
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | taksimo
# Processing Record 15 of Set 5 | tongliao
# Processing Record 16 of Set 5 | lagoa
# Processing Record 17 of Set 5 | kaya
# Processing Record 18 of Set 5 | dolton
# Processing Record 19 of Set 5 | piney green
# Processing Record 20 of Set 5 | nizhneangarsk
# Processing Record 21 of Set 5 | lamar
# Processing Record 22 of Set 5 | abu samrah
# Processing Record 23 of Set 5 | xichang
# Processing Record 24 of Set 5 | chuy
# Processing Record 25 of Set 5 | troitskoye
# Processing Record 26 of Set 5 | guerrero negro
# Processing Record 27 of Set 5 | dwarka
# Processing Record 28 of Set 5 | victor harbor
# Processing Record 29 of Set 5 | puri
# Processing Record 30 of Set 5 | uvat
# Processing Record 31 of Set 5 | saint andrews
# Processing Record 32 of Set 5 | ilo
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | alpine
# Processing Record 36 of Set 5 | terney
# Processing Record 37 of Set 5 | hofn
# Processing Record 38 of Set 5 | bengkulu
# Processing Record 39 of Set 5 | farafangana
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | roald
# Processing Record 42 of Set 5 | unye
# City not found. Skipping...
# Processing Record 43 of Set 5 | yumen
# Processing Record 44 of Set 5 | tiarei
# Processing Record 45 of Set 5 | benguela
# Processing Record 46 of Set 5 | san cristobal
# Processing Record 47 of Set 5 | iralaya
# Processing Record 48 of Set 5 | portree
# Processing Record 49 of Set 5 | saint anthony
# Processing Record 50 of Set 5 | leningradskiy
# Processing Record 1 of Set 6 | otane
# Processing Record 2 of Set 6 | belaya gora
# Processing Record 3 of Set 6 | hermon
# Processing Record 4 of Set 6 | seymchan
# Processing Record 5 of Set 6 | agaro
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | gotsu
# Processing Record 8 of Set 6 | yamada
# Processing Record 9 of Set 6 | borba
# Processing Record 10 of Set 6 | bilma
# Processing Record 11 of Set 6 | bluff
# Processing Record 12 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | tawau
# Processing Record 14 of Set 6 | hyeres
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | mudyuga
# City not found. Skipping...
# Processing Record 18 of Set 6 | kashi
# Processing Record 19 of Set 6 | killybegs
# Processing Record 20 of Set 6 | segezha
# Processing Record 21 of Set 6 | baherden
# Processing Record 22 of Set 6 | los llanos de aridane
# Processing Record 23 of Set 6 | pundaguitan
# Processing Record 24 of Set 6 | san ramon
# Processing Record 25 of Set 6 | iqaluit
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | malakal
# Processing Record 28 of Set 6 | mehamn
# Processing Record 29 of Set 6 | kamaishi
# Processing Record 30 of Set 6 | neuquen
# Processing Record 31 of Set 6 | nouakchott
# Processing Record 32 of Set 6 | qui nhon
# Processing Record 33 of Set 6 | hearst
# Processing Record 34 of Set 6 | ust-maya
# Processing Record 35 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 6 | glendive
# Processing Record 37 of Set 6 | bundaberg
# Processing Record 38 of Set 6 | novobirilyussy
# Processing Record 39 of Set 6 | coihueco
# Processing Record 40 of Set 6 | flin flon
# Processing Record 41 of Set 6 | salalah
# Processing Record 42 of Set 6 | mugur-aksy
# Processing Record 43 of Set 6 | nianzishan
# Processing Record 44 of Set 6 | ust-omchug
# Processing Record 45 of Set 6 | cam ranh
# Processing Record 46 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 6 | hami
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | novocheboksarsk
# Processing Record 1 of Set 7 | benghazi
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | redlands
# Processing Record 4 of Set 7 | panama city
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | arroio grande
# Processing Record 8 of Set 7 | bay roberts
# Processing Record 9 of Set 7 | mikasa
# Processing Record 10 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 7 | chokurdakh
# Processing Record 12 of Set 7 | grand gaube
# Processing Record 13 of Set 7 | keti bandar
# Processing Record 14 of Set 7 | bintulu
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | kiama
# Processing Record 17 of Set 7 | menongue
# Processing Record 18 of Set 7 | butte
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | banjar
# Processing Record 24 of Set 7 | charters towers
# Processing Record 25 of Set 7 | oyo
# Processing Record 26 of Set 7 | sinnamary
# Processing Record 27 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 28 of Set 7 | ushtobe
# Processing Record 29 of Set 7 | sioux lookout
# Processing Record 30 of Set 7 | hernani
# Processing Record 31 of Set 7 | utiel
# Processing Record 32 of Set 7 | beringovskiy
# Processing Record 33 of Set 7 | burnie
# Processing Record 34 of Set 7 | provideniya
# Processing Record 35 of Set 7 | sambava
# Processing Record 36 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 7 | henties bay
# Processing Record 38 of Set 7 | rawson
# Processing Record 39 of Set 7 | tolaga bay
# Processing Record 40 of Set 7 | east london
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 43 of Set 7 | ajdabiya
# Processing Record 44 of Set 7 | chulumani
# Processing Record 45 of Set 7 | castro
# Processing Record 46 of Set 7 | kloulklubed
# Processing Record 47 of Set 7 | atambua
# Processing Record 48 of Set 7 | san juan
# Processing Record 49 of Set 7 | kandava
# Processing Record 50 of Set 7 | acapulco
# Processing Record 1 of Set 8 | vung tau
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | bull savanna
# Processing Record 4 of Set 8 | buraydah
# Processing Record 5 of Set 8 | cockburn town
# Processing Record 6 of Set 8 | pangoa
# Processing Record 7 of Set 8 | paciran
# Processing Record 8 of Set 8 | qasigiannguit
# Processing Record 9 of Set 8 | yelets
# Processing Record 10 of Set 8 | cabedelo
# Processing Record 11 of Set 8 | de aar
# Processing Record 12 of Set 8 | pangody
# Processing Record 13 of Set 8 | hirara
# Processing Record 14 of Set 8 | sorland
# Processing Record 15 of Set 8 | waitati
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | carire
# Processing Record 18 of Set 8 | aripuana
# Processing Record 19 of Set 8 | harper
# Processing Record 20 of Set 8 | hastings
# Processing Record 21 of Set 8 | ghanzi
# Processing Record 22 of Set 8 | marystown
# Processing Record 23 of Set 8 | ostrovnoy
# Processing Record 24 of Set 8 | okha
# Processing Record 25 of Set 8 | conceicao do araguaia
# Processing Record 26 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 8 | luanshya
# Processing Record 28 of Set 8 | sao joao da barra
# Processing Record 29 of Set 8 | nehe
# Processing Record 30 of Set 8 | alyangula
# Processing Record 31 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 8 | kharp
# Processing Record 33 of Set 8 | udachnyy
# Processing Record 34 of Set 8 | grindavik
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | koboko
# Processing Record 37 of Set 8 | tigzirt
# Processing Record 38 of Set 8 | padang
# Processing Record 39 of Set 8 | challapata
# Processing Record 40 of Set 8 | hatillo
# Processing Record 41 of Set 8 | ulladulla
# Processing Record 42 of Set 8 | balkanabat
# Processing Record 43 of Set 8 | porto walter
# Processing Record 44 of Set 8 | abnub
# Processing Record 45 of Set 8 | zhangjiakou
# Processing Record 46 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 8 | quatre cocos
# Processing Record 48 of Set 8 | sotnikovskoye
# Processing Record 49 of Set 8 | cuenca
# Processing Record 50 of Set 8 | adrar
# Processing Record 1 of Set 9 | chuncheng
# Processing Record 2 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | forestville
# Processing Record 5 of Set 9 | spearfish
# Processing Record 6 of Set 9 | moa
# Processing Record 7 of Set 9 | asau
# Processing Record 8 of Set 9 | lianran
# Processing Record 9 of Set 9 | itaituba
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | serro
# Processing Record 12 of Set 9 | lubsko
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | mound
# Processing Record 15 of Set 9 | vikulovo
# Processing Record 16 of Set 9 | kirakira
# Processing Record 17 of Set 9 | elasson
# City not found. Skipping...
# Processing Record 18 of Set 9 | dawlatabad
# Processing Record 19 of Set 9 | sola
# Processing Record 20 of Set 9 | lerwick
# Processing Record 21 of Set 9 | lavrentiya
# Processing Record 22 of Set 9 | marsh harbour
# Processing Record 23 of Set 9 | bambanglipuro
# Processing Record 24 of Set 9 | yakeshi
# Processing Record 25 of Set 9 | ambulu
# Processing Record 26 of Set 9 | yulara
# Processing Record 27 of Set 9 | meridian
# Processing Record 28 of Set 9 | tapes
# Processing Record 29 of Set 9 | le robert
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | nacala
# Processing Record 32 of Set 9 | pemangkat
# Processing Record 33 of Set 9 | tupelo
# Processing Record 34 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | rudbar
# Processing Record 37 of Set 9 | obo
# Processing Record 38 of Set 9 | luderitz
# Processing Record 39 of Set 9 | payo
# Processing Record 40 of Set 9 | airai
# Processing Record 41 of Set 9 | batsfjord
# Processing Record 42 of Set 9 | balabac
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | susangerd
# Processing Record 45 of Set 9 | am timan
# Processing Record 46 of Set 9 | pitsunda
# Processing Record 47 of Set 9 | kavaratti
# Processing Record 48 of Set 9 | bandarbeyla
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | sisimiut
# Processing Record 1 of Set 10 | tourlaville
# Processing Record 2 of Set 10 | polunochnoye
# Processing Record 3 of Set 10 | opuwo
# Processing Record 4 of Set 10 | jilib
# Processing Record 5 of Set 10 | xinxiang
# Processing Record 6 of Set 10 | mao
# Processing Record 7 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 10 | fayaoue
# Processing Record 9 of Set 10 | saint-augustin
# Processing Record 10 of Set 10 | ketchikan
# Processing Record 11 of Set 10 | goundam
# Processing Record 12 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 10 | malatya
# Processing Record 14 of Set 10 | inirida
# Processing Record 15 of Set 10 | zhicheng
# Processing Record 16 of Set 10 | imperial beach
# Processing Record 17 of Set 10 | vestmannaeyjar
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | crateus
# Processing Record 20 of Set 10 | madina
# Processing Record 21 of Set 10 | kapoeta
# Processing Record 22 of Set 10 | chinchani
# Processing Record 23 of Set 10 | port macquarie
# Processing Record 24 of Set 10 | mamou
# Processing Record 25 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 26 of Set 10 | kazachinskoye
# Processing Record 27 of Set 10 | tual
# Processing Record 28 of Set 10 | olafsvik
# Processing Record 29 of Set 10 | la rioja
# Processing Record 30 of Set 10 | evensk
# Processing Record 31 of Set 10 | gambela
# Processing Record 32 of Set 10 | ugoofaaru
# Processing Record 33 of Set 10 | butterworth
# Processing Record 34 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 10 | esik
# Processing Record 36 of Set 10 | la asuncion
# Processing Record 37 of Set 10 | madaoua
# Processing Record 38 of Set 10 | bratsk
# Processing Record 39 of Set 10 | cumpas
# Processing Record 40 of Set 10 | ponta delgada
# Processing Record 41 of Set 10 | bogo
# Processing Record 42 of Set 10 | mareeba
# Processing Record 43 of Set 10 | kirovskiy
# Processing Record 44 of Set 10 | ulaangom
# Processing Record 45 of Set 10 | rovaniemi
# Processing Record 46 of Set 10 | astoria
# Processing Record 47 of Set 10 | uyuni
# Processing Record 48 of Set 10 | dhidhdhoo
# Processing Record 49 of Set 10 | boralday
# Processing Record 50 of Set 10 | vallenar
# Processing Record 1 of Set 11 | sindou
# Processing Record 2 of Set 11 | valparaiso
# Processing Record 3 of Set 11 | porto-vecchio
# Processing Record 4 of Set 11 | wajir
# Processing Record 5 of Set 11 | kavieng
# Processing Record 6 of Set 11 | korla
# Processing Record 7 of Set 11 | ullapool
# Processing Record 8 of Set 11 | berlevag
# Processing Record 9 of Set 11 | shahr-e babak
# Processing Record 10 of Set 11 | quesnel
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | uelzen
# Processing Record 13 of Set 11 | auki
# Processing Record 14 of Set 11 | srednekolymsk
# Processing Record 15 of Set 11 | haga
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | alekseyevka
# Processing Record 18 of Set 11 | borazjan
# Processing Record 19 of Set 11 | umm kaddadah
# Processing Record 20 of Set 11 | naifaru
# Processing Record 21 of Set 11 | sao filipe
# Processing Record 22 of Set 11 | hinganghat
# Processing Record 23 of Set 11 | half moon bay
# Processing Record 24 of Set 11 | belmonte
# Processing Record 25 of Set 11 | abha
# Processing Record 26 of Set 11 | vaitape
# Processing Record 27 of Set 11 | kampong chhnang
# Processing Record 28 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 11 | kajaani
# Processing Record 30 of Set 11 | nortelandia
# Processing Record 31 of Set 11 | cabras
# Processing Record 32 of Set 11 | santa cruz de la palma
# Processing Record 33 of Set 11 | baykit
# Processing Record 34 of Set 11 | alta floresta
# Processing Record 35 of Set 11 | kralendijk
# Processing Record 36 of Set 11 | darnah
# Processing Record 37 of Set 11 | zyryanka
# Processing Record 38 of Set 11 | nabire
# Processing Record 39 of Set 11 | visnes
# Processing Record 40 of Set 11 | jumla
# Processing Record 41 of Set 11 | pekan nenas
# Processing Record 42 of Set 11 | tautira
# Processing Record 43 of Set 11 | barra do garcas
# Processing Record 44 of Set 11 | bogalusa
# Processing Record 45 of Set 11 | gisborne
# Processing Record 46 of Set 11 | pravdinsk
# Processing Record 47 of Set 11 | coihaique
# Processing Record 48 of Set 11 | naze
# Processing Record 49 of Set 11 | mutoko
# Processing Record 50 of Set 11 | kuremaa
# Processing Record 1 of Set 12 | poum
# Processing Record 2 of Set 12 | bridlington
# Processing Record 3 of Set 12 | umea
# Processing Record 4 of Set 12 | brandenburg
# Processing Record 5 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 12 | talaya
# Processing Record 7 of Set 12 | antofagasta
# Processing Record 8 of Set 12 | tiznit
# Processing Record 9 of Set 12 | san carlos
# Processing Record 10 of Set 12 | golden
# Processing Record 11 of Set 12 | tiksi
# Processing Record 12 of Set 12 | khuzhir
# Processing Record 13 of Set 12 | novichikha
# Processing Record 14 of Set 12 | kutum
# Processing Record 15 of Set 12 | hokitika
# Processing Record 16 of Set 12 | san jose
# Processing Record 17 of Set 12 | thinadhoo
# Processing Record 18 of Set 12 | okhotsk
# Processing Record 19 of Set 12 | joshimath
# Processing Record 20 of Set 12 | eston
# Processing Record 21 of Set 12 | coahuayana
# Processing Record 22 of Set 12 | rumonge
# Processing Record 23 of Set 12 | saint-georges
# Processing Record 24 of Set 12 | vera cruz
# Processing Record 25 of Set 12 | kadom
# Processing Record 26 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 12 | kozhva
# Processing Record 28 of Set 12 | sydney mines
# Processing Record 29 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 30 of Set 12 | nioro
# Processing Record 31 of Set 12 | trairi
# Processing Record 32 of Set 12 | bayog
# Processing Record 33 of Set 12 | maromitsa
# Processing Record 34 of Set 12 | salamanca
# Processing Record 35 of Set 12 | mariental
# Processing Record 36 of Set 12 | hirado
# Processing Record 37 of Set 12 | manokwari
# Processing Record 38 of Set 12 | assiniboia
# Processing Record 39 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 12 | ahuimanu
# Processing Record 41 of Set 12 | visby
# Processing Record 42 of Set 12 | arlit
# Processing Record 43 of Set 12 | komsomolskiy
# Processing Record 44 of Set 12 | houston
# Processing Record 45 of Set 12 | batticaloa
# Processing Record 46 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | kalabo
# Processing Record 49 of Set 12 | port-gentil
# Processing Record 50 of Set 12 | metro
# Processing Record 1 of Set 13 | chapais
# Processing Record 2 of Set 13 | dekar
# Processing Record 3 of Set 13 | ukiah
# Processing Record 4 of Set 13 | senno
# Processing Record 5 of Set 13 | tanout
# Processing Record 6 of Set 13 | presidente medici
# Processing Record 7 of Set 13 | hoquiam
# Processing Record 8 of Set 13 | roebourne
# Processing Record 9 of Set 13 | olinda
# Processing Record 10 of Set 13 | gumdag
# Processing Record 11 of Set 13 | maarianhamina
# Processing Record 12 of Set 13 | kathmandu
# Processing Record 13 of Set 13 | saurimo
# Processing Record 14 of Set 13 | shizuishan
# Processing Record 15 of Set 13 | emerald
# Processing Record 16 of Set 13 | fjerritslev
# Processing Record 17 of Set 13 | ishinomaki
# Processing Record 18 of Set 13 | san quintin
# Processing Record 19 of Set 13 | medicine hat
# Processing Record 20 of Set 13 | san carlos de bariloche
# Processing Record 21 of Set 13 | kawalu
# Processing Record 22 of Set 13 | dossor
# Processing Record 23 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 13 | hobyo
# Processing Record 25 of Set 13 | jurmala
# Processing Record 26 of Set 13 | samarai
# Processing Record 27 of Set 13 | casa nova
# Processing Record 28 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 13 | nieuwpoort
# Processing Record 30 of Set 13 | ipixuna
# Processing Record 31 of Set 13 | teya
# Processing Record 32 of Set 13 | bambous virieux
# Processing Record 33 of Set 13 | ferrol
# Processing Record 34 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 13 | dzerzhinsk
# Processing Record 36 of Set 13 | menomonie
# Processing Record 37 of Set 13 | comodoro rivadavia
# Processing Record 38 of Set 13 | calama
# Processing Record 39 of Set 13 | ankola
# Processing Record 40 of Set 13 | nuuk
# Processing Record 41 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 13 | sao felix do xingu
# Processing Record 43 of Set 13 | yangjiang
# Processing Record 44 of Set 13 | thai binh
# Processing Record 45 of Set 13 | sobolevo
# Processing Record 46 of Set 13 | daru
# Processing Record 47 of Set 13 | boende
# Processing Record 48 of Set 13 | fairbanks
# Processing Record 49 of Set 13 | yanam
# Processing Record 50 of Set 13 | hutang
# Processing Record 1 of Set 14 | saysain
# Processing Record 2 of Set 14 | homer
# Processing Record 3 of Set 14 | meulaboh
# Processing Record 4 of Set 14 | luanda
# Processing Record 5 of Set 14 | alice springs
# Processing Record 6 of Set 14 | labuhan
# Processing Record 7 of Set 14 | topeka
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | guanajuato
# Processing Record 10 of Set 14 | banepa
# Processing Record 11 of Set 14 | jawhar
# Processing Record 12 of Set 14 | humaita
# Processing Record 13 of Set 14 | abu dhabi
# Processing Record 14 of Set 14 | uyovu
# Processing Record 15 of Set 14 | ozinki
# Processing Record 16 of Set 14 | sibolga
# Processing Record 17 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 18 of Set 14 | alberton
# Processing Record 19 of Set 14 | santa marta
# Processing Record 20 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 14 | liverpool
# Processing Record 22 of Set 14 | koungou
# Processing Record 23 of Set 14 | nome
# Processing Record 24 of Set 14 | cobija
# Processing Record 25 of Set 14 | souillac
# Processing Record 26 of Set 14 | kulhudhuffushi
# Processing Record 27 of Set 14 | bereda
# Processing Record 28 of Set 14 | qiryat shemona
# Processing Record 29 of Set 14 | senahu
# Processing Record 30 of Set 14 | araouane
# Processing Record 31 of Set 14 | santa clara
# Processing Record 32 of Set 14 | sechura
# Processing Record 33 of Set 14 | hamilton
# Processing Record 34 of Set 14 | smidovich
# Processing Record 35 of Set 14 | shirgaon
# Processing Record 36 of Set 14 | collie
# Processing Record 37 of Set 14 | coromandel
# Processing Record 38 of Set 14 | port hardy
# Processing Record 39 of Set 14 | cuamba
# Processing Record 40 of Set 14 | shihezi
# Processing Record 41 of Set 14 | christchurch
# Processing Record 42 of Set 14 | kisangani
# Processing Record 43 of Set 14 | bumba
# Processing Record 44 of Set 14 | zhangye
# Processing Record 45 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 14 | sindor
# Processing Record 47 of Set 14 | maragogi
# Processing Record 48 of Set 14 | nantucket
# Processing Record 49 of Set 14 | phrai bung
# City not found. Skipping...
# Processing Record 50 of Set 14 | kresttsy
# Processing Record 1 of Set 15 | avera
# Processing Record 2 of Set 15 | playa del carmen
# Processing Record 3 of Set 15 | rosarito
# Processing Record 4 of Set 15 | mushie
# Processing Record 5 of Set 15 | frunze
# Processing Record 6 of Set 15 | biak
# Processing Record 7 of Set 15 | sao jose de piranhas
# Processing Record 8 of Set 15 | augusto correa
# Processing Record 9 of Set 15 | libreville
# Processing Record 10 of Set 15 | puerto del rosario
# Processing Record 11 of Set 15 | botwood
# Processing Record 12 of Set 15 | bom jesus
# Processing Record 13 of Set 15 | tchollire
# Processing Record 14 of Set 15 | saravena
# Processing Record 15 of Set 15 | omsukchan
# Processing Record 16 of Set 15 | grand-santi
# Processing Record 17 of Set 15 | isiro
# Processing Record 18 of Set 15 | phumi samraong
# City not found. Skipping...
# Processing Record 19 of Set 15 | polovinnoye
# Processing Record 20 of Set 15 | kiruna
# Processing Record 21 of Set 15 | belogradcik
# City not found. Skipping...
# Processing Record 22 of Set 15 | praxedis guerrero
# Processing Record 23 of Set 15 | seoul
# Processing Record 24 of Set 15 | hohhot
# Processing Record 25 of Set 15 | blythe
# Processing Record 26 of Set 15 | wakkanai
# Processing Record 27 of Set 15 | birjand
# Processing Record 28 of Set 15 | walvis bay
# Processing Record 29 of Set 15 | gladstone
# Processing Record 30 of Set 15 | arona
# Processing Record 31 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 15 | tevaitoa
# Processing Record 33 of Set 15 | turukhansk
# Processing Record 34 of Set 15 | verkhnyaya toyma
# Processing Record 35 of Set 15 | biograd na moru
# Processing Record 36 of Set 15 | kotido
# Processing Record 37 of Set 15 | katakwi
# Processing Record 38 of Set 15 | suntar
# Processing Record 39 of Set 15 | oliver
# Processing Record 40 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 15 | gaozhou
# Processing Record 42 of Set 15 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     80.56        54           0
# 1           Torbay      CA  47.6666  -52.7314     74.17        71          90
# 2           Hasaki      JP  35.7333  140.8333     68.40        93         100
# 3         Almaznyy      RU  48.0448   40.0450     75.34        84          76
# 4         Tasiilaq      GL  65.6145  -37.6368     51.96        70          14
# 5        Busselton      AU -33.6500  115.3333     56.08        71          82
# 6         Borujerd      IR  33.8973   48.7516     75.85        13          10
# 7           Atuona      PF  -9.8000 -139.0333     77.27        82          19
# 8          Ushuaia      AR -54.8000  -68.3000     47.86        53           0
# 9   Port Elizabeth      ZA -33.9180   25.5701     59.29        44           0
#
#    Wind Speed Current Description
# 0       17.27           clear sky
# 1       25.32     overcast clouds
# 2       14.32     overcast clouds
# 3        5.91       broken clouds
# 4        5.17          few clouds
# 5       16.15       broken clouds
# 6        4.12           clear sky
# 7       22.28          light rain
# 8        9.22           clear sky
# 9        3.44           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_weather.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
city_weather['weather'][0]['description']
# Out:
# 'scattered clouds'
